# %%
from statistics.knowledge import show_graph, showg, load, save, append as app

# %%
progs = ["dot","neato","fdp","sfdp","circo","twopi","nop","nop2","osage","patchwork"]

# %%
d = {}

app(d, 'Сочинение', "Подражание")
app(d, "Подражание", ['чем способ', "чему предмет", "как способ"])
app(d, "как способ", ["ускувство","навык","дар"])
app(d, 'чем способ', ['ритм', "мелодия", "слово"])

# app(d,'','')

# app(d,'','')
app(d, 'метр','творить+метр')
app(d, 'творить+метр',["элегики","эпики"])
app(d,'слово', ["триметр", "элегический", 'метр', "без размера"])
app(d, "ритм", ['ритм+мелодия',"танец"])
app(d, "мелодия", 'ритм+мелодия')
app(d, 'ритм+мелодия', ["авлетика", "кифаристика","сврель"])
app(d,'ритм','ритм мелодия метр')
app(d,'мелодия','ритм мелодия метр')
app(d,'метр','ритм мелодия метр')

app(d,'ритм мелодия метр',["ном", "трагедия", "комедия", "дифирабмическая поэзия" ])
app(d, "Подражание", "подражатели")
app(d, "подражатели", "действующие лица")
app(d, "чему предмет", "действующие лица")
app(d, "действующие лица", ["хорошие лучшие", "дурные худшие", "обыкновенные"])
app(d, "хорошие лучшие",["Полигтон"])
app(d, "обыкновенные",["Дионисий", "Клеофтон"])
app(d, "дурные худшие",["Павсон", "Гегемон", "Никохар"])

app(d, "трагедия", "хорошие лучшие")
app(d, "комедия", "дурные худшие")
app(d, "Подражание", "подражание как способ")
app(d, "как способ", "подражание как способ")
app(d, "подражание как способ", ["персонажи отдельно от себя","остаться самим собой","персонажи действующие и деятельные"])

app(d, "Детство", "Подражание")
app(d, "Детство", "Детство Подражание")
app(d, "Подражание", "Детство Подражание")
app(d, "Подражание", "Удовольствие")
app(d, "Детство Подражание","Знание")




show_graph(d, prog='dot', node_size=900, font_size=11, figsize=(14,10))

# %%
sho
